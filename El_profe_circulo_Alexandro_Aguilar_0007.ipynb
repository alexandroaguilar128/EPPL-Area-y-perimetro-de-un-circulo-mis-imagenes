# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandroaguilar128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/blob/main/El_profe_circulo_Alexandro_Aguilar_0007.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Alexandro Aguilar NL = 1 Fecha 25/Mar/2026
# ---
# # Calcular area y perimetro de un circulo
# ---
# ![Logo de Markdown](https://raw.githubusercontent.com/alexandroaguilar128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/circulo_area_perimetro.PNG)
#
# ---
# ## Formula para calcular Area
# $A=\pi*r^2$
#
# ---
# ## Formula para calcular perimetro
# $P=2*\pi*r$
# ---
# ## Datos de entrada
# $r$ ?
# ---
# ## Diagrama de flujo en Lucidchart
# ![](https://raw.githubusercontent.com/alexandroaguilar128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/DF%20Area%20perimetro%20circulo.png)

# %%
# Calcular Area y perimetro de un circulo
# Variable A, P, r
# formulas A = pi*r^2 y P = 2 * pi * r
# Capturar el valor de r
import math
print("Calcular area y perimetro de un circulo")
r = float(input("Ingrese el valor deL radio: "))
A = math.pi * r**2
P = 2 * math.pi * r
print("El area del circulo es: ", A)
print("El perimetro del circulo es: ", P)
print("Alexandro Aguilar NL = 1")
# Out:
# Calcular area y perimetro de un circulo
# Ingrese el valor de r: 8
# El area del circulo es:  201.06192982974676
# El perimetro del circulo es:  50.26548245743669
# Alexandro Aguilar NL = 1

# %% [markdown]
# # Relacion entre codigo y diagrama de flujo en tldraw
# ![](https://raw.githubusercontent.com/alexandroaguilar128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/tldraw%20DF%20y%20codigo.png)
